# %%
import pandas as pd
import numpy as np
import time

# %%
pd.read_csv("advertising_dataset.csv")
# Out:
#      Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0             0                     68.95  35.0     61833.90
# 1             1                     80.23  31.0     68441.85
# 2             2                     69.47  26.0     59785.94
# 3             3                     74.15  29.0     54806.18
# 4             4                     68.37  35.0     73889.99
# ..          ...                       ...   ...          ...
# 995         995                     72.97  30.0     71384.57
# 996         996                     51.30  45.0     67782.17
# 997         997                     51.63  51.0     42415.72
# 998         998                     55.55  19.0     41920.79
# 999         999                       NaN  26.0     29875.80
#
#      Daily Internet Usage                          Ad Topic Line  \
# 0                  256.09     Cloned 5thgeneration orchestration
# 1                     NaN     Monitored national standardization
# ...

# %%
advertising_df = pd.read_csv("advertising_dataset.csv")
advertising_df.head()
# Out:
#    Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0           0                     68.95  35.0     61833.90
# 1           1                     80.23  31.0     68441.85
# 2           2                     69.47  26.0     59785.94
# 3           3                     74.15  29.0     54806.18
# 4           4                     68.37  35.0     73889.99
#
#    Daily Internet Usage                          Ad Topic Line  \
# 0                256.09     Cloned 5thgeneration orchestration
# 1                   NaN     Monitored national standardization
# 2                236.50       Organic bottom-line service-desk
# 3                245.89  Triple-buffered reciprocal time-frame
# 4                225.58          Robust logistical utilization
#
#              City  Gender     Country            Timestamp  Clicked on Ad
# 0     Wrightburgh  Female     Tunisia  2016-03-27 00:53:11            0.0
# 1       West Jodi    Male       Nauru  2016-04-04 01:39:02            0.0
# ...

# %%
advertising_df.tail()
# Out:
#      Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 995         995                     72.97  30.0     71384.57
# 996         996                     51.30  45.0     67782.17
# 997         997                     51.63  51.0     42415.72
# 998         998                     55.55  19.0     41920.79
# 999         999                       NaN  26.0     29875.80
#
#      Daily Internet Usage                         Ad Topic Line  \
# 995                208.58         Fundamental modular algorithm
# 996                134.42       Grass-roots cohesive monitoring
# 997                120.37          Expanded intangible solution
# 998                187.95  Proactive bandwidth-monitored policy
# 999                178.35       Virtual 5thgeneration emulation
#
#               City  Gender                 Country            Timestamp  \
# 995      Duffystad    Male                 Lebanon  2016-02-11 21:49:00
# ...

# %%
advertising_df.describe()
# Out:
#         Unnamed: 0  Daily Time Spent on Site         Age   Area Income  \
# count  1000.000000                907.000000  979.000000   1000.000000
# mean    499.500000                 64.794818   36.009193  55000.000080
# std     288.819436                 15.954841    8.783636  13414.634022
# min       0.000000                 32.600000   19.000000  13996.500000
# 25%     249.750000                 50.615000   29.000000  47031.802500
# 50%     499.500000                 67.940000   35.000000  57012.300000
# 75%     749.250000                 78.555000   42.000000  65470.635000
# max     999.000000                 91.430000   61.000000  79484.800000
#
#        Daily Internet Usage  Clicked on Ad
# count            913.000000     832.000000
# mean             179.751271       0.496394
# std               43.957934       0.500288
# min              104.780000       0.000000
# 25%              138.550000       0.000000
# 50%              183.480000       0.000000
# ...

# %%
advertising_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1000 non-null   int64
#  1   Daily Time Spent on Site  907 non-null    float64
#  2   Age                       979 non-null    float64
#  3   Area Income               1000 non-null   float64
#  4   Daily Internet Usage      913 non-null    float64
#  5   Ad Topic Line             1000 non-null   object
#  6   City                      1000 non-null   object
#  7   Gender                    1000 non-null   object
#  8   Country                   1000 non-null   object
#  9   Timestamp                 1000 non-null   object
#  10  Clicked on Ad             832 non-null    float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 86.1+ KB

# %%
dummy = pd.get_dummies(advertising_df['Gender'])
dummy.head()
# Out:
#    Female  Male
# 0       1     0
# 1       0     1
# 2       1     0
# 3       0     1
# 4       1     0

# %%
advertising_df = pd.concat((advertising_df,dummy), axis=1)
advertising_df.head()
# Out:
#    Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0           0                     68.95  35.0     61833.90
# 1           1                     80.23  31.0     68441.85
# 2           2                     69.47  26.0     59785.94
# 3           3                     74.15  29.0     54806.18
# 4           4                     68.37  35.0     73889.99
#
#    Daily Internet Usage                          Ad Topic Line  \
# 0                256.09     Cloned 5thgeneration orchestration
# 1                   NaN     Monitored national standardization
# 2                236.50       Organic bottom-line service-desk
# 3                245.89  Triple-buffered reciprocal time-frame
# 4                225.58          Robust logistical utilization
#
#              City  Gender     Country            Timestamp  Clicked on Ad  \
# 0     Wrightburgh  Female     Tunisia  2016-03-27 00:53:11            0.0
# 1       West Jodi    Male       Nauru  2016-04-04 01:39:02            0.0
# ...

# %%
advertising_df = advertising_df.drop(['Gender'], axis=1)

# %%
advertising_df.head(20)
# Out:
#     Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0            0                     68.95  35.0     61833.90
# 1            1                     80.23  31.0     68441.85
# 2            2                     69.47  26.0     59785.94
# 3            3                     74.15  29.0     54806.18
# 4            4                     68.37  35.0     73889.99
# 5            5                     59.99  23.0     59761.56
# 6            6                     88.91  33.0     53852.85
# 7            7                     66.00  48.0     24593.33
# 8            8                     74.53  30.0     68862.00
# 9            9                     69.88  20.0     55642.32
# 10          10                     47.64  49.0     45632.51
# 11          11                     83.07  37.0     62491.01
# 12          12                       NaN  48.0     51636.92
# 13          13                     79.52   NaN     51739.63
# 14          14                     42.95  33.0     30976.00
# ...

# %%
advertising_df = advertising_df.drop(['Female'], axis=1)

# %%
advertising_df.head()
# Out:
#    Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0           0                     68.95  35.0     61833.90
# 1           1                     80.23  31.0     68441.85
# 2           2                     69.47  26.0     59785.94
# 3           3                     74.15  29.0     54806.18
# 4           4                     68.37  35.0     73889.99
#
#    Daily Internet Usage                          Ad Topic Line  \
# 0                256.09     Cloned 5thgeneration orchestration
# 1                   NaN     Monitored national standardization
# 2                236.50       Organic bottom-line service-desk
# 3                245.89  Triple-buffered reciprocal time-frame
# 4                225.58          Robust logistical utilization
#
#              City     Country            Timestamp  Clicked on Ad  Male
# 0     Wrightburgh     Tunisia  2016-03-27 00:53:11            0.0     0
# 1       West Jodi       Nauru  2016-04-04 01:39:02            0.0     1
# ...

# %%
advertising_df = advertising_df.rename(columns={"Male":"Gender"})

# %%
advertising_df.head()
# Out:
#    Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0           0                     68.95  35.0     61833.90
# 1           1                     80.23  31.0     68441.85
# 2           2                     69.47  26.0     59785.94
# 3           3                     74.15  29.0     54806.18
# 4           4                     68.37  35.0     73889.99
#
#    Daily Internet Usage                          Ad Topic Line  \
# 0                256.09     Cloned 5thgeneration orchestration
# 1                   NaN     Monitored national standardization
# 2                236.50       Organic bottom-line service-desk
# 3                245.89  Triple-buffered reciprocal time-frame
# 4                225.58          Robust logistical utilization
#
#              City     Country            Timestamp  Clicked on Ad  Gender
# 0     Wrightburgh     Tunisia  2016-03-27 00:53:11            0.0       0
# 1       West Jodi       Nauru  2016-04-04 01:39:02            0.0       1
# ...

# %%
print(advertising_df['Age'].isnull().sum())
# Out:
# 21

# %%
advertising_df['Daily Time Spent on Site'] = advertising_df['Daily Time Spent on Site'].fillna(advertising_df['Daily Time Spent on Site'].mean())

# %%
advertising_df['Age'] = advertising_df['Age'].fillna(advertising_df['Age'].mean())

# %%
advertising_df['Daily Internet Usage'] = advertising_df['Daily Internet Usage'].fillna(advertising_df['Daily Internet Usage'].mean())

# %%
advertising_df.head(20)
# Out:
#     Unnamed: 0  Daily Time Spent on Site        Age  Area Income  \
# 0            0                 68.950000  35.000000     61833.90
# 1            1                 80.230000  31.000000     68441.85
# 2            2                 69.470000  26.000000     59785.94
# 3            3                 74.150000  29.000000     54806.18
# 4            4                 68.370000  35.000000     73889.99
# 5            5                 59.990000  23.000000     59761.56
# 6            6                 88.910000  33.000000     53852.85
# 7            7                 66.000000  48.000000     24593.33
# 8            8                 74.530000  30.000000     68862.00
# 9            9                 69.880000  20.000000     55642.32
# 10          10                 47.640000  49.000000     45632.51
# 11          11                 83.070000  37.000000     62491.01
# 12          12                 64.794818  48.000000     51636.92
# ...

# %%
advertising_df['Gender'].value_counts()
# Out:
# 0    519
# 1    481
# Name: Gender, dtype: int64

# %%
print(advertising_df['Clicked on Ad'].isnull().sum())
# Out:
# 168

# %%
advertising_df['Clicked on Ad'].value_counts()
# Out:
# 0.0    419
# 1.0    413
# Name: Clicked on Ad, dtype: int64

# %%
df_age_older = advertising_df["Age"] > 21

# %%
advertising_df[(advertising_df["Age"] > 21) & (advertising_df['Gender'] == 1)]
# Out:
#      Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 1             1                     80.23  31.0     68441.85
# 3             3                     74.15  29.0     54806.18
# 5             5                     59.99  23.0     59761.56
# 7             7                     66.00  48.0     24593.33
# 8             8                     74.53  30.0     68862.00
# ..          ...                       ...   ...          ...
# 991         991                     38.96  38.0     36497.22
# 993         993                     64.20  27.0     66200.96
# 995         995                     72.97  30.0     71384.57
# 996         996                     51.30  45.0     67782.17
# 997         997                     51.63  51.0     42415.72
#
#      Daily Internet Usage                           Ad Topic Line  \
# 1              179.751271      Monitored national standardization
# 3              245.890000   Triple-buffered reciprocal time-frame
# ...

# %%
df_age_older
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998    False
# 999     True
# Name: Age, Length: 1000, dtype: bool

# %%
df_age_older.value_counts()
# Out:
# True     982
# False     18
# Name: Age, dtype: int64

# %%
advertising_df[advertising_df['Clicked on Ad'] == 1].mean()
# Out:
# Unnamed: 0                    504.515738
# Daily Time Spent on Site       54.283823
# Age                            40.295600
# Area Income                 48311.036247
# Daily Internet Usage          148.108473
# Clicked on Ad                   1.000000
# Gender                          0.476998
# dtype: float64

# %%
tic = time.time()
advertising_df[advertising_df['Clicked on Ad'] == 1].mean()
toc = time.time()

print("vectorization: %f ms" % ((toc - tic) * 1000))
# Out:
# vectorization: 5.110502 ms

# %%
advertising_df[advertising_df['Clicked on Ad'] == 0].mean()
# Out:
# Unnamed: 0                    489.472554
# Daily Time Spent on Site       75.644958
# Age                            31.723326
# Area Income                 61390.286802
# Daily Internet Usage          211.848555
# Clicked on Ad                   0.000000
# Gender                          0.505967
# dtype: float64

# %%
tic = time.time()
advertising_df[advertising_df['Clicked on Ad'] == 0].mean()
toc = time.time()

print("vectorization: %f ms" % ((toc - tic) * 1000))
# Out:
# vectorization: 4.640102 ms

# %%
ClickedCounter = 0
UnClickedCounter = 0
AgeOfClicked = 0
AgeOfUnClicked = 0
meanOfClicked = 0
meanOfUnClicked = 0
tic = time.time()
for i in range(len(advertising_df)): 
    if (advertising_df.loc[i, "Clicked on Ad"] == 1):
        AgeOfClicked += advertising_df.loc[i, "Age"]
        ClickedCounter +=1 
    if (advertising_df.loc[i, "Clicked on Ad"] == 0):
        AgeOfUnClicked += advertising_df.loc[i, "Age"]
        UnClickedCounter += 1
meanOfClicked = AgeOfClicked/ClickedCounter
meanOfUnClicked = AgeOfUnClicked/UnClickedCounter
toc = time.time()
print("meanOfClicked: %f " % meanOfClicked)
print("meanOfUnClicked: %f " % meanOfUnClicked)
print("for loop: %f ms" % ((toc - tic) * 1000))
# Out:
# meanOfClicked: 40.295600
# meanOfUnClicked: 31.723326
# for loop: 26.316881 ms

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
advertising_df.hist('Age')
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
advertising_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Daily Time Spent on Site'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'Area Income'}>,
#         <AxesSubplot:title={'center':'Daily Internet Usage'}>,
#         <AxesSubplot:title={'center':'Clicked on Ad'}>],
#        [<AxesSubplot:title={'center':'Gender'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_S9 = advertising_df.drop(['Ad Topic Line', 'City' , 'Gender' , 'Country' , 'Timestamp' , 'Unnamed: 0'], axis=1)

# %%
df_S9.head(15)
# Out:
#     Daily Time Spent on Site        Age  Area Income  Daily Internet Usage  \
# 0                  68.950000  35.000000     61833.90            256.090000
# 1                  80.230000  31.000000     68441.85            179.751271
# 2                  69.470000  26.000000     59785.94            236.500000
# 3                  74.150000  29.000000     54806.18            245.890000
# 4                  68.370000  35.000000     73889.99            225.580000
# 5                  59.990000  23.000000     59761.56            226.740000
# 6                  88.910000  33.000000     53852.85            208.360000
# 7                  66.000000  48.000000     24593.33            131.760000
# 8                  74.530000  30.000000     68862.00            221.510000
# 9                  69.880000  20.000000     55642.32            183.820000
# 10                 47.640000  49.000000     45632.51            122.020000
# ...

# %%
def z_score(df):
    df_std = df.copy()
    for column in df_std[['Daily Time Spent on Site', 'Age' , 'Area Income', 'Daily Internet Usage']]:
        df_std[column] = (df_std[column] - df_std[column].mean()) / df_std[column].std()
        
    return df_std
    
df_ad_standardized = z_score(df_S9)

df_ad_standardized
# Out:
#      Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 0                    0.273474 -0.116122     0.509436              1.817578
# 1                    1.015870 -0.576377     1.002029              0.000000
# 2                    0.307698 -1.151696     0.356770              1.351152
# 3                    0.615713 -0.806505    -0.014448              1.574722
# 4                    0.235301 -0.116122     1.408163              1.091154
# ..                        ...       ...          ...                   ...
# 995                  0.538051 -0.691441     1.221395              0.686394
# 996                 -0.888164  1.034517     0.952853             -1.079309
# 997                 -0.866445  1.724900    -0.938101             -1.413831
# 998                 -0.608450 -1.957144    -0.974996              0.195207
# 999                  0.000000 -1.151696    -1.872895             -0.033363
#
#      Clicked on Ad
# 0              0.0
# 1              0.0
# ...

# %%
df_ad_standardized[df_ad_standardized['Clicked on Ad'] == 1].mean()
# Out:
# Daily Time Spent on Site   -0.691783
# Age                         0.493211
# Area Income                -0.498632
# Daily Internet Usage       -0.753395
# Clicked on Ad               1.000000
# dtype: float64

# %%
df_ad_standardized[df_ad_standardized['Clicked on Ad'] == 0].mean()
# Out:
# Daily Time Spent on Site    0.714104
# Age                        -0.493148
# Area Income                 0.476367
# Daily Internet Usage        0.764216
# Clicked on Ad               0.000000
# dtype: float64

# %%
df_ad_standardized[df_ad_standardized['Clicked on Ad'] == 1].std()
# Out:
# Daily Time Spent on Site    0.836161
# Age                         1.019268
# Area Income                 1.046199
# Daily Internet Usage        0.723959
# Clicked on Ad               0.000000
# dtype: float64

# %%
df_ad_standardized[df_ad_standardized['Clicked on Ad'] == 0].std()
# Out:
# Daily Time Spent on Site    0.531369
# Age                         0.706315
# Area Income                 0.670476
# Daily Internet Usage        0.592058
# Clicked on Ad               0.000000
# dtype: float64

# %%
df_ad_standardized.head(50)
# Out:
#     Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 0                   0.273474 -0.116122     0.509436              1.817578
# 1                   1.015870 -0.576377     1.002029              0.000000
# 2                   0.307698 -1.151696     0.356770              1.351152
# 3                   0.615713 -0.806505    -0.014448              1.574722
# 4                   0.235301 -0.116122     1.408163              1.091154
# 5                  -0.316230 -1.496888     0.354953              1.118772
# 6                   1.587145 -0.346249    -0.085515              0.681156
# 7                   0.079319  1.379709    -2.266679             -1.142642
# 8                   0.640723 -0.691441     1.033349              0.994249
# 9                   0.334682 -1.842080     0.047882              0.096874
# 10                 -1.129048  1.494773    -0.698304             -1.374546
# 11                  1.202785  0.114006     0.558421              0.000000
# ...

# %%
import scipy.stats as ss

x = df_ad_standardized['Age']
mu1 = 0.493211
sigma1 = 1.019268
mu2 = -0.493148
sigma2 = 0.706315
y_pdf = ss.norm.pdf(x, mu1, sigma1) 
plt.plot(x, y_pdf, label='pdf-Age-Clicked')
z_pdf = ss.norm.pdf(x, mu2, sigma2) 
plt.plot(x, z_pdf, label='pdf-Age-Unclicked')
plt.legend();

# %%
x = df_ad_standardized['Daily Time Spent on Site']
mu1 = -0.691783
sigma1 = 0.836161
mu2 = 0.714104
sigma2 = 0.531369
y_pdf = ss.norm.pdf(x, mu1, sigma1) 
plt.plot(x, y_pdf, label='pdf-Daily Time Spent on Site-Clicked')
z_pdf = ss.norm.pdf(x, mu2, sigma2) 
plt.plot(x, z_pdf, label='pdf-Daily Time Spent on Site-Unclicked')
plt.legend();

# %%
x = df_ad_standardized['Area Income']
mu1 = -0.498632
sigma1 = 1.046199
mu2 = 0.476367
sigma2 = 0.670476
y_pdf = ss.norm.pdf(x, mu1, sigma1) 
plt.plot(x, y_pdf, label='pdf-Area Income-Clicked')
z_pdf = ss.norm.pdf(x, mu2, sigma2) 
plt.plot(x, z_pdf, label='pdf-Area Income-Unclicked')
plt.legend();

# %%
x = df_ad_standardized['Daily Internet Usage']
mu1 = -0.753395
sigma1 = 0.723959
mu2 = 0.764216
sigma2 = 0.592058
y_pdf = ss.norm.pdf(x, mu1, sigma1) 
plt.plot(x, y_pdf, label='pdf-Daily Internet Usage-Clicked')
z_pdf = ss.norm.pdf(x, mu2, sigma2) 
plt.plot(x, z_pdf, label='pdf-Daily Internet Usage-Unclicked')
plt.legend();

# %%
mu1 = -0.691783
sigma1 = 0.836161
mu2 = 0.714104
sigma2 = 0.531369
for i in range(len(df_ad_standardized)): 
    if(df_ad_standardized["Clicked on Ad"].isnull()[i]):
        if(mu1 -sigma1 < df_ad_standardized.loc[i, "Daily Time Spent on Site"] < mu1+sigma1):
            df_ad_standardized.loc[i, "Clicked on Ad"] = 1
        if(mu2 - sigma2 < df_ad_standardized.loc[i, "Daily Time Spent on Site"] < mu2+sigma2):
            df_ad_standardized.loc[i, "Clicked on Ad"] = 0

# %%
mu1 = -0.753395
sigma1 = 0.723959
mu2 = 0.764216
sigma2 = 0.592058
for i in range(len(df_ad_standardized)): 
    if(df_ad_standardized["Clicked on Ad"].isnull()[i]):
        if(mu1 -sigma1 < df_ad_standardized.loc[i, "Daily Internet Usage"] < mu1+sigma1):
            df_ad_standardized.loc[i, "Clicked on Ad"] = 1
        if(mu2 - sigma2 < df_ad_standardized.loc[i, "Daily Internet Usage"] < mu2+sigma2):
            df_ad_standardized.loc[i, "Clicked on Ad"] = 0

# %%
df_ad_standardized.head(50)
# Out:
#     Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 0                   0.273474 -0.116122     0.509436              1.817578
# 1                   1.015870 -0.576377     1.002029              0.000000
# 2                   0.307698 -1.151696     0.356770              1.351152
# 3                   0.615713 -0.806505    -0.014448              1.574722
# 4                   0.235301 -0.116122     1.408163              1.091154
# 5                  -0.316230 -1.496888     0.354953              1.118772
# 6                   1.587145 -0.346249    -0.085515              0.681156
# 7                   0.079319  1.379709    -2.266679             -1.142642
# 8                   0.640723 -0.691441     1.033349              0.994249
# 9                   0.334682 -1.842080     0.047882              0.096874
# 10                 -1.129048  1.494773    -0.698304             -1.374546
# 11                  1.202785  0.114006     0.558421              0.000000
# ...
